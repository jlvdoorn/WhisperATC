# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Colors

# %%
#     Blue                       Green                       Red                             Yellow
## Face Color (Soft/Fill)
c1 = [(0.5373, 0.8941, 1.0, 1.0), (0.4549, 1.0, 0.9373, 1.0), (0.9529, 0.6667, 0.5647, 1.0), (0.9686, 0.8471, 0.5451, 1.0)] # 80% alpha
c2 = [(0.5373, 0.8941, 1.0, 0.8), (0.4549, 1.0, 0.9373, 0.8), (0.9529, 0.6667, 0.5647, 0.8), (0.9686, 0.8471, 0.5451, 0.8)] # 60% alpha
c3 = [(0.5373, 0.8941, 1.0, 0.6), (0.4549, 1.0, 0.9373, 0.6), (0.9529, 0.6667, 0.5647, 0.6), (0.9686, 0.8471, 0.5451, 0.6)] # 40% alpha
c4 = [(0.5373, 0.8941, 1.0, 0.4), (0.4549, 1.0, 0.9373, 0.4), (0.9529, 0.6667, 0.5647, 0.4), (0.9686, 0.8471, 0.5451, 0.4)] # 20% alpha
## Edge Color (Hard/Outline)
e1 = [(0.0, 0.6510, 0.8392, 1.0), (0.0, 0.6392, 0.5647, 1.0), (0.9216, 0.4471, 0.2745, 1.0), (0.8314, 0.6118, 0.0588, 1.0)] # 80% alpha
e2 = [(0.0, 0.6510, 0.8392, 0.8), (0.0, 0.6392, 0.5647, 0.8), (0.9216, 0.4471, 0.2745, 0.8), (0.8314, 0.6118, 0.0588, 0.8)] # 60% alpha
e3 = [(0.0, 0.6510, 0.8392, 0.6), (0.0, 0.6392, 0.5647, 0.6), (0.9216, 0.4471, 0.2745, 0.6), (0.8314, 0.6118, 0.0588, 0.6)] # 40% alpha
e4 = [(0.0, 0.6510, 0.8392, 0.4), (0.0, 0.6392, 0.5647, 0.4), (0.9216, 0.4471, 0.2745, 0.4), (0.8314, 0.6118, 0.0588, 0.4)] # 20% alpha

# %% [markdown]
# # Basics

# %% [markdown]
# ## Normalization and Prompting Effect

# %%
labels = ['ATCO2', 'ATCOSIM', 'Average'] # Norm/Prompt

nn = [42.27, 78.72, 60.50]
yn = [23.89, 23.44, 23.67]
ny = [23.71, 27.66, 25.69]
yy = [9.73, 3.12, 6.43]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, nn, width/2, label='No Prompt/No Normalizer', color=[c1[0], c1[0], c1[0]], edgecolor=[e1[0], e1[0], e1[0]])
r2 = ax.bar(x-width/4, yn, width/2, label='No Prompt/Normalizer', color=[c1[1], c1[1], c1[1]], edgecolor=[e1[1], e1[1], e1[1]])
r3 = ax.bar(x+width/4, ny, width/2, label='Prompt/No Normalizer', color=[c1[2], c1[2], c1[2]], edgecolor=[e1[2], e1[2], e1[2]])
r4 = ax.bar(x+3*width/4, yy, width/2, label='Prompt/Normalizer', color=[c1[3], c1[3], c1[3]], edgecolor=[e1[3], e1[3], e1[3]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('WER Effect of Prompting and Normalization')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125), shadow=False, ncol=2, title='Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('wer_effect_prompt_norm.pdf', format='pdf', bbox_inches='tight')
fig.savefig('wer_effect_prompt_norm.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Baseline Performance

# %%
labels = ['ATCO2 T+V', 'ATCO2 V', 'ATCOSIM T+V', 'ATCOSIM V']

# #     Blue                       Green                       Red
# ## Face Color (Soft/Fill)
# c1 = [(0.5373, 0.8941, 1.0, 1.0), (0.4549, 1.0, 0.9373, 1.0), (0.9529, 0.6667, 0.5647, 1.0)] # 80% alpha
# c2 = [(0.5373, 0.8941, 1.0, 0.8), (0.4549, 1.0, 0.9373, 0.8), (0.9529, 0.6667, 0.5647, 0.8)] # 60% alpha
# c3 = [(0.5373, 0.8941, 1.0, 0.6), (0.4549, 1.0, 0.9373, 0.6), (0.9529, 0.6667, 0.5647, 0.6)] # 40% alpha
# c4 = [(0.5373, 0.8941, 1.0, 0.4), (0.4549, 1.0, 0.9373, 0.4), (0.9529, 0.6667, 0.5647, 0.4)] # 20% alpha
# ## Edge Color (Hard/Outline)
# e1 = [(0.0, 0.6510, 0.8392, 1.0), (0.0, 0.6392, 0.5647, 1.0), (0.9216, 0.4471, 0.2745, 1.0)] # 80% alpha
# e2 = [(0.0, 0.6510, 0.8392, 0.8), (0.0, 0.6392, 0.5647, 0.8), (0.9216, 0.4471, 0.2745, 0.8)] # 60% alpha
# e3 = [(0.0, 0.6510, 0.8392, 0.6), (0.0, 0.6392, 0.5647, 0.6), (0.9216, 0.4471, 0.2745, 0.6)] # 40% alpha
# e4 = [(0.0, 0.6510, 0.8392, 0.4), (0.0, 0.6392, 0.5647, 0.4), (0.9216, 0.4471, 0.2745, 0.4)] # 20% alpha

# Bars (No/No - Yes/No - No/Yes - Yes/Yes) - Normalizer/Prompt
nn = [71.60, 71.62, 79.70, 79.11]
yn = [31.45, 29.05, 18.14, 17.98]
ny = [63.91, 61.08, 64.10, 63.62]
yy = [27.14, 24.03, 17.10, 16.74]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, nn, width/2, label='No Prompt/No Normalizer', color=[c1[0], c1[0], c1[0], c1[0]], edgecolor=[e1[0], e1[0], e1[0], e1[0]])
r2 = ax.bar(x-width/4, yn, width/2, label='No Prompt/Normalizer', color=[c1[1], c1[1], c1[1], c1[1]], edgecolor=[e1[1], e1[1], e1[1], e1[1]])
r3 = ax.bar(x+width/4, ny, width/2, label='Prompt/No Normalizer', color=[c1[2], c1[2], c1[2], c1[2]], edgecolor=[e1[2], e1[2], e1[2], e1[2]])
r4 = ax.bar(x+3*width/4, yy, width/2, label='Prompt/Normalizer', color=[c1[3], c1[3], c1[3], c1[3]], edgecolor=[e1[3], e1[3], e1[3], e1[3]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Baseline Performance of Whisper Large-v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125), shadow=False, ncol=2, title='Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('baseline_performance.pdf', format='pdf', bbox_inches='tight')
fig.savefig('baseline_performance.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# # Fine-Tuned

# %% [markdown]
# ## Fine-Tuning Performance

# %%
labels = ['ATCO2\nT+V', 'ATCO2\nV', 'ATCOSIM\nT+V', 'ATCOSIM\nV', 'A2-AS\nT+V', 'A2-AS\nV']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06]
whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78]
whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42]
whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, whisper, width/2, label='Blank', color=[c1[0], c1[0], c1[0], c1[0], c1[0], c1[0]], edgecolor=[e1[0], e1[0], e1[0], e1[0], e1[0], e1[0]])
r2 = ax.bar(x-width/4, whisper_atco2, width/2, label='ATCO2', color=[c1[1], c1[1], c1[1], c1[1], c1[1], c1[1]], edgecolor=[e1[1], e1[1], e1[1], e1[1], e1[1], e1[1]])
r3 = ax.bar(x+width/4, whisper_atcosim, width/2, label='ATCOSIM', color=[c1[2], c1[2], c1[2], c1[2], c1[2], c1[2]], edgecolor=[e1[2], e1[2], e1[2], e1[2], e1[2], e1[2]])
r4 = ax.bar(x+3*width/4, whisper_atco2_atcosim, width/2, label='ATCO2-ATCOSIM', color=[c1[3], c1[3], c1[3], c1[3], c1[3], c1[3]], edgecolor=[e1[3], e1[3], e1[3], e1[3], e1[3], e1[3]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=2, title='Model Variant')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('fine-tuned_performance.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuned_performance.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Fine-Tuned Performance (Validation Split Only)

# %%
labels = ['ATCO2\nV', 'ATCOSIM\nV', 'A2-AS\nV']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
whisper = [24.03, 16.74, 17.06]
whisper_atco2 = [14.66, 15.84, 15.78]
whisper_atcosim = [34.34, 1.19, 4.42]
whisper_atco2_atcosim = [13.46, 1.17, 2.41]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, whisper, width/2, label='Blank', color=c1[0], edgecolor=e1[0])
r2 = ax.bar(x-width/4, whisper_atco2, width/2, label='ATCO2', color=c1[1], edgecolor=e1[1])
r3 = ax.bar(x+width/4, whisper_atcosim, width/2, label='ATCOSIM', color=c1[2], edgecolor=e1[2])
r4 = ax.bar(x+3*width/4, whisper_atco2_atcosim, width/2, label='ATCO2-ATCOSIM', color=c1[3], edgecolor=e1[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=2, title='Model Variant')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('fine-tuned_performance_validation.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuned_performance_validation.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Fine-Tuned Performance (All Metrics --> Appendix)

# %%
labels = ['ATCO2\nT+V', 'ATCO2\nV', 'ATCOSIM\nT+V', 'ATCOSIM\nV', 'A2-AS\nT+V', 'A2-AS\nV']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
# whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06]
# whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78]
# whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42]
# whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41]

whisper =                   [[71.6036, 31.4536, 63.9084, 27.1403], [71.6192, 29.0538, 61.0765, 24.0338], [79.6975, 18.1356, 64.1035, 17.1018], [79.1119, 17.9776, 63.6183, 16.7376], [78.9677, 19.3505, 64.2925, 17.8668], [78.4055, 19.0331, 63.3073, 17.0604]]
whisper_atco2 =             [[ 6.1898,  5.7698,  6.9752,  5.2189], [19.7064, 17.8587, 18.1495, 14.6602], [49.3092, 16.0503, 45.671 , 16.2996], [48.4812, 15.8392, 44.6147, 15.9515], [45.4211, 15.1125, 41.9795, 15.2692], [45.7683, 16.0317, 41.9519, 15.7777]]
whisper_atcosim =           [[57.784 , 38.6238, 59.0556, 40.2297], [53.5142, 34.3403, 54.4039, 35.3621], [ 0.341 ,  0.343 ,  0.316 ,  0.3168], [ 1.2502,  1.2634,  1.1854,  1.1932], [ 5.5207,  3.8352,  5.616 ,  3.9612], [ 6.1777,  4.4154,  6.207 ,  4.4535]]
whisper_atco2_atcosim =     [[ 5.4979,  4.9015,  9.1912,  4.8828], [17.2598, 14.5713, 19.395 , 13.4607], [ 0.2548,  0.2568,  0.2845,  0.2877], [ 1.1669,  1.1792,  1.2271,  1.2447], [ 0.7276,  0.6805,  1.0885,  0.7078], [ 2.6841,  2.4553,  2.9399,  2.4088]]

# A/B --- Prompt/Normalizer
whisper_nn =                [whisper[0][0], whisper[1][0], whisper[2][0], whisper[3][0], whisper[4][0], whisper[5][0]]
whisper_ny =                [whisper[0][1], whisper[1][1], whisper[2][1], whisper[3][1], whisper[4][1], whisper[5][1]]
whisper_yn =                [whisper[0][2], whisper[1][2], whisper[2][2], whisper[3][2], whisper[4][2], whisper[5][2]]
whisper_yy =                [whisper[0][3], whisper[1][3], whisper[2][3], whisper[3][3], whisper[4][3], whisper[5][3]]

whisper_atco2_nn =          [whisper_atco2[0][0], whisper_atco2[1][0], whisper_atco2[2][0], whisper_atco2[3][0], whisper_atco2[4][0], whisper_atco2[5][0]]
whisper_atco2_ny =          [whisper_atco2[0][1], whisper_atco2[1][1], whisper_atco2[2][1], whisper_atco2[3][1], whisper_atco2[4][1], whisper_atco2[5][1]]
whisper_atco2_yn =          [whisper_atco2[0][2], whisper_atco2[1][2], whisper_atco2[2][2], whisper_atco2[3][2], whisper_atco2[4][2], whisper_atco2[5][2]]
whisper_atco2_yy =          [whisper_atco2[0][3], whisper_atco2[1][3], whisper_atco2[2][3], whisper_atco2[3][3], whisper_atco2[4][3], whisper_atco2[5][3]]

whisper_atcosim_nn =        [whisper_atcosim[0][0], whisper_atcosim[1][0], whisper_atcosim[2][0], whisper_atcosim[3][0], whisper_atcosim[4][0], whisper_atcosim[5][0]]
whisper_atcosim_ny =        [whisper_atcosim[0][1], whisper_atcosim[1][1], whisper_atcosim[2][1], whisper_atcosim[3][1], whisper_atcosim[4][1], whisper_atcosim[5][1]]
whisper_atcosim_yn =        [whisper_atcosim[0][2], whisper_atcosim[1][2], whisper_atcosim[2][2], whisper_atcosim[3][2], whisper_atcosim[4][2], whisper_atcosim[5][2]]
whisper_atcosim_yy =        [whisper_atcosim[0][3], whisper_atcosim[1][3], whisper_atcosim[2][3], whisper_atcosim[3][3], whisper_atcosim[4][3], whisper_atcosim[5][3]]

whisper_atco2_atcosim_nn =  [whisper_atco2_atcosim[0][0], whisper_atco2_atcosim[1][0], whisper_atco2_atcosim[2][0], whisper_atco2_atcosim[3][0], whisper_atco2_atcosim[4][0], whisper_atco2_atcosim[5][0]]
whisper_atco2_atcosim_ny =  [whisper_atco2_atcosim[0][1], whisper_atco2_atcosim[1][1], whisper_atco2_atcosim[2][1], whisper_atco2_atcosim[3][1], whisper_atco2_atcosim[4][1], whisper_atco2_atcosim[5][1]]
whisper_atco2_atcosim_yn =  [whisper_atco2_atcosim[0][2], whisper_atco2_atcosim[1][2], whisper_atco2_atcosim[2][2], whisper_atco2_atcosim[3][2], whisper_atco2_atcosim[4][2], whisper_atco2_atcosim[5][2]]
whisper_atco2_atcosim_yy =  [whisper_atco2_atcosim[0][3], whisper_atco2_atcosim[1][3], whisper_atco2_atcosim[2][3], whisper_atco2_atcosim[3][3], whisper_atco2_atcosim[4][3], whisper_atco2_atcosim[5][3]]

# %%
x = np.arange(len(labels))  # the label locations
n = 16
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1   = ax.bar(x-(n- 1)*width/n, whisper_nn,                  width/24, label='Blank (-/-)',         color=c1[0], edgecolor=e1[0]) 
r2   = ax.bar(x-(n- 3)*width/n, whisper_atco2_nn,            width/24, label='ATCO2 (-/-)',         color=c1[1], edgecolor=e1[1])
r3   = ax.bar(x-(n- 5)*width/n, whisper_atcosim_nn,          width/24, label='ATCOSIM (-/-)',       color=c1[2], edgecolor=e1[2])
r4   = ax.bar(x-(n- 7)*width/n, whisper_atco2_atcosim_nn,    width/24, label='ATCO2-ATCOSIM (-/-)', color=c1[3], edgecolor=e1[3])
r5   = ax.bar(x-(n- 9)*width/n, whisper_ny,                  width/24, label='Blank (-/n)',         color=c2[0], edgecolor=e2[0])
r6   = ax.bar(x-(n-11)*width/n, whisper_atco2_ny,            width/24, label='ATCO2 (-/n)',         color=c2[1], edgecolor=e2[1])
r7   = ax.bar(x-(n-13)*width/n, whisper_atcosim_ny,          width/24, label='ATCOSIM (-/n)',       color=c2[2], edgecolor=e2[2])
r8   = ax.bar(x-(n-15)*width/n, whisper_atco2_atcosim_ny,    width/24, label='ATCO2-ATCOSIM (-/n)', color=c2[3], edgecolor=e2[3])
r9   = ax.bar(x+(n-15)*width/n, whisper_yn,                  width/24, label='Blank (p/-)',         color=c3[0], edgecolor=e3[0])
r10  = ax.bar(x+(n-13)*width/n, whisper_atco2_yn,            width/24, label='ATCO2 (p/-)',         color=c3[1], edgecolor=e3[1])
r11  = ax.bar(x+(n-11)*width/n, whisper_atcosim_yn,          width/24, label='ATCOSIM (p/-)',       color=c3[2], edgecolor=e3[2])
r12  = ax.bar(x+(n- 9)*width/n, whisper_atco2_atcosim_yn,    width/24, label='ATCO2-ATCOSIM (p/-)', color=c3[3], edgecolor=e3[3])
r13  = ax.bar(x+(n- 7)*width/n, whisper_yy,                  width/24, label='Blank (p/n)',         color=c4[0], edgecolor=e4[0])
r14  = ax.bar(x+(n- 5)*width/n, whisper_atco2_yy,            width/24, label='ATCO2 (p/n)',         color=c4[1], edgecolor=e4[1])
r15  = ax.bar(x+(n- 3)*width/n, whisper_atcosim_yy,          width/24, label='ATCOSIM (p/n)',       color=c4[2], edgecolor=e4[2])
r16  = ax.bar(x+(n- 1)*width/n, whisper_atco2_atcosim_yy,    width/24, label='ATCO2-ATCOSIM (p/n)', color=c4[3], edgecolor=e4[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=4, title='Model Variant & Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)
fig.set_figwidth(15)

# %%
fig.savefig('fine-tuned_performance_all.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuned_performance_all.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Fine-Tuned Performance (Validation Split Only --- All Metrics --> Appendix)

# %%
labels = ['ATCO2\nV', 'ATCOSIM\nV', 'A2-AS\nV']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
# whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06]
# whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78]
# whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42]
# whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41]

# Model        -- # Dataset           ATCO2 (V)                             ATCOSIM (V)                             ATCO2-ATCOSIM (V)
whisper =                   [[71.6192, 29.0538, 61.0765, 24.0338], [79.1119, 17.9776, 63.6183, 16.7376], [78.4055, 19.0331, 63.3073, 17.0604]]
whisper_atco2 =             [[19.7064, 17.8587, 18.1495, 14.6602], [48.4812, 15.8392, 44.6147, 15.9515], [45.7683, 16.0317, 41.9519, 15.7777]]
whisper_atcosim =           [[53.5142, 34.3403, 54.4039, 35.3621], [ 1.2502,  1.2634,  1.1854,  1.1932], [ 6.1777,  4.4154,  6.207 ,  4.4535]]
whisper_atco2_atcosim =     [[17.2598, 14.5713, 19.395 , 13.4607], [ 1.1669,  1.1792,  1.2271,  1.2447], [ 2.6841,  2.4553,  2.9399,  2.4088]]

# (A/B) = (Prompt/Norm)
whisper_nn =                [whisper[0][0], whisper[1][0], whisper[2][0]]
whisper_ny =                [whisper[0][1], whisper[1][1], whisper[2][1]]
whisper_yn =                [whisper[0][2], whisper[1][2], whisper[2][2]]
whisper_yy =                [whisper[0][3], whisper[1][3], whisper[2][3]]

whisper_atco2_nn =          [whisper_atco2[0][0], whisper_atco2[1][0], whisper_atco2[2][0]]
whisper_atco2_ny =          [whisper_atco2[0][1], whisper_atco2[1][1], whisper_atco2[2][1]]
whisper_atco2_yn =          [whisper_atco2[0][2], whisper_atco2[1][2], whisper_atco2[2][2]]
whisper_atco2_yy =          [whisper_atco2[0][3], whisper_atco2[1][3], whisper_atco2[2][3]]

whisper_atcosim_nn =        [whisper_atcosim[0][0], whisper_atcosim[1][0], whisper_atcosim[2][0]]
whisper_atcosim_ny =        [whisper_atcosim[0][1], whisper_atcosim[1][1], whisper_atcosim[2][1]]
whisper_atcosim_yn =        [whisper_atcosim[0][2], whisper_atcosim[1][2], whisper_atcosim[2][2]]
whisper_atcosim_yy =        [whisper_atcosim[0][3], whisper_atcosim[1][3], whisper_atcosim[2][3]]

whisper_atco2_atcosim_nn =  [whisper_atco2_atcosim[0][0], whisper_atco2_atcosim[1][0], whisper_atco2_atcosim[2][0]]
whisper_atco2_atcosim_ny =  [whisper_atco2_atcosim[0][1], whisper_atco2_atcosim[1][1], whisper_atco2_atcosim[2][1]]
whisper_atco2_atcosim_yn =  [whisper_atco2_atcosim[0][2], whisper_atco2_atcosim[1][2], whisper_atco2_atcosim[2][2]]
whisper_atco2_atcosim_yy =  [whisper_atco2_atcosim[0][3], whisper_atco2_atcosim[1][3], whisper_atco2_atcosim[2][3]]

# %%
x = np.arange(len(labels))  # the label locations
n = 16
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1   = ax.bar(x-(n- 1)*width/n, whisper_nn,                  width/24, label='Blank (-/-)',         color=c1[0], edgecolor=e1[0]) 
r2   = ax.bar(x-(n- 3)*width/n, whisper_atco2_nn,            width/24, label='ATCO2 (-/-)',         color=c1[1], edgecolor=e1[1])
r3   = ax.bar(x-(n- 5)*width/n, whisper_atcosim_nn,          width/24, label='ATCOSIM (-/-)',       color=c1[2], edgecolor=e1[2])
r4   = ax.bar(x-(n- 7)*width/n, whisper_atco2_atcosim_nn,    width/24, label='ATCO2-ATCOSIM (-/-)', color=c1[3], edgecolor=e1[3])
r5   = ax.bar(x-(n- 9)*width/n, whisper_ny,                  width/24, label='Blank (-/n)',         color=c2[0], edgecolor=e2[0])
r6   = ax.bar(x-(n-11)*width/n, whisper_atco2_ny,            width/24, label='ATCO2 (-/n)',         color=c2[1], edgecolor=e2[1])
r7   = ax.bar(x-(n-13)*width/n, whisper_atcosim_ny,          width/24, label='ATCOSIM (-/n)',       color=c2[2], edgecolor=e2[2])
r8   = ax.bar(x-(n-15)*width/n, whisper_atco2_atcosim_ny,    width/24, label='ATCO2-ATCOSIM (-/n)', color=c2[3], edgecolor=e2[3])
r9   = ax.bar(x+(n-15)*width/n, whisper_yn,                  width/24, label='Blank (p/-)',         color=c3[0], edgecolor=e3[0])
r10  = ax.bar(x+(n-13)*width/n, whisper_atco2_yn,            width/24, label='ATCO2 (p/-)',         color=c3[1], edgecolor=e3[1])
r11  = ax.bar(x+(n-11)*width/n, whisper_atcosim_yn,          width/24, label='ATCOSIM (p/-)',       color=c3[2], edgecolor=e3[2])
r12  = ax.bar(x+(n- 9)*width/n, whisper_atco2_atcosim_yn,    width/24, label='ATCO2-ATCOSIM (p/-)', color=c3[3], edgecolor=e3[3])
r13  = ax.bar(x+(n- 7)*width/n, whisper_yy,                  width/24, label='Blank (p/n)',         color=c4[0], edgecolor=e4[0])
r14  = ax.bar(x+(n- 5)*width/n, whisper_atco2_yy,            width/24, label='ATCO2 (p/n)',         color=c4[1], edgecolor=e4[1])
r15  = ax.bar(x+(n- 3)*width/n, whisper_atcosim_yy,          width/24, label='ATCOSIM (p/n)',       color=c4[2], edgecolor=e4[2])
r16  = ax.bar(x+(n- 1)*width/n, whisper_atco2_atcosim_yy,    width/24, label='ATCO2-ATCOSIM (p/n)', color=c4[3], edgecolor=e4[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=4, title='Model Variant & Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)
fig.set_figwidth(15)

# %%
fig.savefig('fine-tuned_performance_all_validation.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuned_performance_all_validation.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# # ANSP

# %% [markdown]
# ## Performance on ANSP Dataset

# %%
labels = ['ATCO2\nT+V', 'ATCO2\nV', 'ATCOSIM\nT+V', 'ATCOSIM\nV', 'A2-AS\nT+V', 'A2-AS\nV', 'ANSP']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06, 33.16]
whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78, 25.57]
whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42, 55.88]
whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41, 24.42]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, whisper, width/2, label='Blank', color=c1[0], edgecolor=e1[0])
r2 = ax.bar(x-width/4, whisper_atco2, width/2, label='ATCO2', color=c1[1], edgecolor=e1[1])
r3 = ax.bar(x+width/4, whisper_atcosim, width/2, label='ATCOSIM', color=c1[2], edgecolor=e1[2])
r4 = ax.bar(x+3*width/4, whisper_atco2_atcosim, width/2, label='ATCO2-ATCOSIM', color=c1[3], edgecolor=e1[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=2, title='Model Variant')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('ANSP_performance.pdf', format='pdf', bbox_inches='tight')
fig.savefig('ANSP_performance.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Performance on ANSP Dataset (Validation Only)

# %%
labels = ['ATCO2\nV', 'ATCOSIM\nV', 'A2-AS\nV', 'ANSP']

# Bars
whisper = [24.03, 16.74, 17.06, 33.16]
whisper_atco2 = [14.66, 15.84, 15.78, 25.57]
whisper_atcosim = [34.34, 1.19, 4.42, 55.88]
whisper_atco2_atcosim = [13.46, 1.17, 2.41, 24.42]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, whisper, width/2, label='Blank', color=c1[0], edgecolor=e1[0])
r2 = ax.bar(x-width/4, whisper_atco2, width/2, label='ATCO2', color=c1[1], edgecolor=e1[1])
r3 = ax.bar(x+width/4, whisper_atcosim, width/2, label='ATCOSIM', color=c1[2], edgecolor=e1[2])
r4 = ax.bar(x+3*width/4, whisper_atco2_atcosim, width/2, label='ATCO2-ATCOSIM', color=c1[3], edgecolor=e1[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=2, title='Model Variant')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('ANSP_performance_validation.pdf', format='pdf', bbox_inches='tight')
fig.savefig('ANSP_performance_validation.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Performance on ANSP Dataset (All Metrics)

# %%
labels = ['ATCO2\nT+V', 'ATCO2\nV', 'ATCOSIM\nT+V', 'ATCOSIM\nV', 'A2-AS\nT+V', 'A2-AS\nV', 'ANSP']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V - ANSP
#                                                                                                                                                                                                                                                                 -/-      -/N      P/-      P/N
whisper =                   [[71.6036, 31.4536, 63.9084, 27.1403], [71.6192, 29.0538, 61.0765, 24.0338], [79.6975, 18.1356, 64.1035, 17.1018], [79.1119, 17.9776, 63.6183, 16.7376], [78.9677, 19.3505, 64.2925, 17.8668], [78.4055, 19.0331, 63.3073, 17.0604], [78.5931, 34.1170, 66.4261, 33.1607]]
whisper_atco2 =             [[ 6.1898,  5.7698,  6.9752,  5.2189], [19.7064, 17.8587, 18.1495, 14.6602], [49.3092, 16.0503, 45.671 , 16.2996], [48.4812, 15.8392, 44.6147, 15.9515], [45.4211, 15.1125, 41.9795, 15.2692], [45.7683, 16.0317, 41.9519, 15.7777], [39.9183, 25.9795, 38.0440, 25.5722]]
whisper_atcosim =           [[57.784 , 38.6238, 59.0556, 40.2297], [53.5142, 34.3403, 54.4039, 35.3621], [ 0.341 ,  0.343 ,  0.316 ,  0.3168], [ 1.2502,  1.2634,  1.1854,  1.1932], [ 5.5207,  3.8352,  5.616 ,  3.9612], [ 6.1777,  4.4154,  6.207 ,  4.4535], [63.0497, 55.8817, 68.8405, 63.5675]]
whisper_atco2_atcosim =     [[ 5.4979,  4.9015,  9.1912,  4.8828], [17.2598, 14.5713, 19.395 , 13.4607], [ 0.2548,  0.2568,  0.2845,  0.2877], [ 1.1669,  1.1792,  1.2271,  1.2447], [ 0.7276,  0.6805,  1.0885,  0.7078], [ 2.6841,  2.4553,  2.9399,  2.4088], [37.1228, 24.4211, 24.7470, 25.3154]]

# A/B --- Prompt/Normalizer
whisper_nn =                [whisper[0][0], whisper[1][0], whisper[2][0], whisper[3][0], whisper[4][0], whisper[5][0], whisper[6][0]]
whisper_ny =                [whisper[0][1], whisper[1][1], whisper[2][1], whisper[3][1], whisper[4][1], whisper[5][1], whisper[6][1]]
whisper_yn =                [whisper[0][2], whisper[1][2], whisper[2][2], whisper[3][2], whisper[4][2], whisper[5][2], whisper[6][2]]
whisper_yy =                [whisper[0][3], whisper[1][3], whisper[2][3], whisper[3][3], whisper[4][3], whisper[5][3], whisper[6][3]]

whisper_atco2_nn =          [whisper_atco2[0][0], whisper_atco2[1][0], whisper_atco2[2][0], whisper_atco2[3][0], whisper_atco2[4][0], whisper_atco2[5][0], whisper_atco2[6][0]]
whisper_atco2_ny =          [whisper_atco2[0][1], whisper_atco2[1][1], whisper_atco2[2][1], whisper_atco2[3][1], whisper_atco2[4][1], whisper_atco2[5][1], whisper_atco2[6][1]]
whisper_atco2_yn =          [whisper_atco2[0][2], whisper_atco2[1][2], whisper_atco2[2][2], whisper_atco2[3][2], whisper_atco2[4][2], whisper_atco2[5][2], whisper_atco2[6][2]]
whisper_atco2_yy =          [whisper_atco2[0][3], whisper_atco2[1][3], whisper_atco2[2][3], whisper_atco2[3][3], whisper_atco2[4][3], whisper_atco2[5][3], whisper_atco2[6][3]]

whisper_atcosim_nn =        [whisper_atcosim[0][0], whisper_atcosim[1][0], whisper_atcosim[2][0], whisper_atcosim[3][0], whisper_atcosim[4][0], whisper_atcosim[5][0], whisper_atcosim[6][0]]
whisper_atcosim_ny =        [whisper_atcosim[0][1], whisper_atcosim[1][1], whisper_atcosim[2][1], whisper_atcosim[3][1], whisper_atcosim[4][1], whisper_atcosim[5][1], whisper_atcosim[6][1]]
whisper_atcosim_yn =        [whisper_atcosim[0][2], whisper_atcosim[1][2], whisper_atcosim[2][2], whisper_atcosim[3][2], whisper_atcosim[4][2], whisper_atcosim[5][2], whisper_atcosim[6][2]]
whisper_atcosim_yy =        [whisper_atcosim[0][3], whisper_atcosim[1][3], whisper_atcosim[2][3], whisper_atcosim[3][3], whisper_atcosim[4][3], whisper_atcosim[5][3], whisper_atcosim[6][3]]

whisper_atco2_atcosim_nn =  [whisper_atco2_atcosim[0][0], whisper_atco2_atcosim[1][0], whisper_atco2_atcosim[2][0], whisper_atco2_atcosim[3][0], whisper_atco2_atcosim[4][0], whisper_atco2_atcosim[5][0], whisper_atco2_atcosim[6][0]]
whisper_atco2_atcosim_ny =  [whisper_atco2_atcosim[0][1], whisper_atco2_atcosim[1][1], whisper_atco2_atcosim[2][1], whisper_atco2_atcosim[3][1], whisper_atco2_atcosim[4][1], whisper_atco2_atcosim[5][1], whisper_atco2_atcosim[6][1]]
whisper_atco2_atcosim_yn =  [whisper_atco2_atcosim[0][2], whisper_atco2_atcosim[1][2], whisper_atco2_atcosim[2][2], whisper_atco2_atcosim[3][2], whisper_atco2_atcosim[4][2], whisper_atco2_atcosim[5][2], whisper_atco2_atcosim[6][2]]
whisper_atco2_atcosim_yy =  [whisper_atco2_atcosim[0][3], whisper_atco2_atcosim[1][3], whisper_atco2_atcosim[2][3], whisper_atco2_atcosim[3][3], whisper_atco2_atcosim[4][3], whisper_atco2_atcosim[5][3], whisper_atco2_atcosim[6][3]]

# %%
x = np.arange(len(labels))  # the label locations
n = 16
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1   = ax.bar(x-(n- 1)*width/n, whisper_nn,                  width/24, label='Blank (-/-)',         color=c1[0], edgecolor=e1[0]) 
r2   = ax.bar(x-(n- 3)*width/n, whisper_atco2_nn,            width/24, label='ATCO2 (-/-)',         color=c1[1], edgecolor=e1[1])
r3   = ax.bar(x-(n- 5)*width/n, whisper_atcosim_nn,          width/24, label='ATCOSIM (-/-)',       color=c1[2], edgecolor=e1[2])
r4   = ax.bar(x-(n- 7)*width/n, whisper_atco2_atcosim_nn,    width/24, label='ATCO2-ATCOSIM (-/-)', color=c1[3], edgecolor=e1[3])
r5   = ax.bar(x-(n- 9)*width/n, whisper_ny,                  width/24, label='Blank (-/n)',         color=c2[0], edgecolor=e2[0])
r6   = ax.bar(x-(n-11)*width/n, whisper_atco2_ny,            width/24, label='ATCO2 (-/n)',         color=c2[1], edgecolor=e2[1])
r7   = ax.bar(x-(n-13)*width/n, whisper_atcosim_ny,          width/24, label='ATCOSIM (-/n)',       color=c2[2], edgecolor=e2[2])
r8   = ax.bar(x-(n-15)*width/n, whisper_atco2_atcosim_ny,    width/24, label='ATCO2-ATCOSIM (-/n)', color=c2[3], edgecolor=e2[3])
r9   = ax.bar(x+(n-15)*width/n, whisper_yn,                  width/24, label='Blank (p/-)',         color=c3[0], edgecolor=e3[0])
r10  = ax.bar(x+(n-13)*width/n, whisper_atco2_yn,            width/24, label='ATCO2 (p/-)',         color=c3[1], edgecolor=e3[1])
r11  = ax.bar(x+(n-11)*width/n, whisper_atcosim_yn,          width/24, label='ATCOSIM (p/-)',       color=c3[2], edgecolor=e3[2])
r12  = ax.bar(x+(n- 9)*width/n, whisper_atco2_atcosim_yn,    width/24, label='ATCO2-ATCOSIM (p/-)', color=c3[3], edgecolor=e3[3])
r13  = ax.bar(x+(n- 7)*width/n, whisper_yy,                  width/24, label='Blank (p/n)',         color=c4[0], edgecolor=e4[0])
r14  = ax.bar(x+(n- 5)*width/n, whisper_atco2_yy,            width/24, label='ATCO2 (p/n)',         color=c4[1], edgecolor=e4[1])
r15  = ax.bar(x+(n- 3)*width/n, whisper_atcosim_yy,          width/24, label='ATCOSIM (p/n)',       color=c4[2], edgecolor=e4[2])
r16  = ax.bar(x+(n- 1)*width/n, whisper_atco2_atcosim_yy,    width/24, label='ATCO2-ATCOSIM (p/n)', color=c4[3], edgecolor=e4[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=4, title='Model Variant & Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)
fig.set_figwidth(15)

# %%
fig.savefig('ANSP_performance_all.pdf', format='pdf', bbox_inches='tight')
fig.savefig('ANSP_performance_all.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# ## Performance on ANSP Dataset (All Metrics - Validation Only)

# %%
labels = ['ATCO2\nV', 'ATCOSIM\nV', 'A2-AS\nV', 'ANSP']

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
# whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06]
# whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78]
# whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42]
# whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41]

whisper =                   [[71.6192, 29.0538, 61.0765, 24.0338], [79.1119, 17.9776, 63.6183, 16.7376], [78.4055, 19.0331, 63.3073, 17.0604], [78.5931, 34.1170, 66.4261, 33.1607]]
whisper_atco2 =             [[19.7064, 17.8587, 18.1495, 14.6602], [48.4812, 15.8392, 44.6147, 15.9515], [45.7683, 16.0317, 41.9519, 15.7777], [39.9183, 25.9795, 38.0440, 25.5722]]
whisper_atcosim =           [[53.5142, 34.3403, 54.4039, 35.3621], [ 1.2502,  1.2634,  1.1854,  1.1932], [ 6.1777,  4.4154,  6.207 ,  4.4535], [63.0497, 55.8817, 68.8405, 63.5675]]
whisper_atco2_atcosim =     [[17.2598, 14.5713, 19.395 , 13.4607], [ 1.1669,  1.1792,  1.2271,  1.2447], [ 2.6841,  2.4553,  2.9399,  2.4088], [37.1228, 24.4211, 24.7470, 25.3154]]

# (A/B) = (Prompt/Norm)
whisper_nn =                [whisper[0][0], whisper[1][0], whisper[2][0], whisper[3][0]]
whisper_ny =                [whisper[0][1], whisper[1][1], whisper[2][1], whisper[3][1]]
whisper_yn =                [whisper[0][2], whisper[1][2], whisper[2][2], whisper[3][2]]
whisper_yy =                [whisper[0][3], whisper[1][3], whisper[2][3], whisper[3][3]]

whisper_atco2_nn =          [whisper_atco2[0][0], whisper_atco2[1][0], whisper_atco2[2][0], whisper_atco2[3][0]]
whisper_atco2_ny =          [whisper_atco2[0][1], whisper_atco2[1][1], whisper_atco2[2][1], whisper_atco2[3][1]]
whisper_atco2_yn =          [whisper_atco2[0][2], whisper_atco2[1][2], whisper_atco2[2][2], whisper_atco2[3][2]]
whisper_atco2_yy =          [whisper_atco2[0][3], whisper_atco2[1][3], whisper_atco2[2][3], whisper_atco2[3][3]]

whisper_atcosim_nn =        [whisper_atcosim[0][0], whisper_atcosim[1][0], whisper_atcosim[2][0], whisper_atcosim[3][0]]
whisper_atcosim_ny =        [whisper_atcosim[0][1], whisper_atcosim[1][1], whisper_atcosim[2][1], whisper_atcosim[3][1]]
whisper_atcosim_yn =        [whisper_atcosim[0][2], whisper_atcosim[1][2], whisper_atcosim[2][2], whisper_atcosim[3][2]]
whisper_atcosim_yy =        [whisper_atcosim[0][3], whisper_atcosim[1][3], whisper_atcosim[2][3], whisper_atcosim[3][3]]

whisper_atco2_atcosim_nn =  [whisper_atco2_atcosim[0][0], whisper_atco2_atcosim[1][0], whisper_atco2_atcosim[2][0], whisper_atco2_atcosim[3][0]]
whisper_atco2_atcosim_ny =  [whisper_atco2_atcosim[0][1], whisper_atco2_atcosim[1][1], whisper_atco2_atcosim[2][1], whisper_atco2_atcosim[3][1]]
whisper_atco2_atcosim_yn =  [whisper_atco2_atcosim[0][2], whisper_atco2_atcosim[1][2], whisper_atco2_atcosim[2][2], whisper_atco2_atcosim[3][2]]
whisper_atco2_atcosim_yy =  [whisper_atco2_atcosim[0][3], whisper_atco2_atcosim[1][3], whisper_atco2_atcosim[2][3], whisper_atco2_atcosim[3][3]]

# %%
x = np.arange(len(labels))  # the label locations
n = 16
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1   = ax.bar(x-(n- 1)*width/n, whisper_nn,                  width/24, label='Blank (-/-)',         color=c1[0], edgecolor=e1[0]) 
r2   = ax.bar(x-(n- 3)*width/n, whisper_atco2_nn,            width/24, label='ATCO2 (-/-)',         color=c1[1], edgecolor=e1[1])
r3   = ax.bar(x-(n- 5)*width/n, whisper_atcosim_nn,          width/24, label='ATCOSIM (-/-)',       color=c1[2], edgecolor=e1[2])
r4   = ax.bar(x-(n- 7)*width/n, whisper_atco2_atcosim_nn,    width/24, label='ATCO2-ATCOSIM (-/-)', color=c1[3], edgecolor=e1[3])
r5   = ax.bar(x-(n- 9)*width/n, whisper_ny,                  width/24, label='Blank (-/n)',         color=c2[0], edgecolor=e2[0])
r6   = ax.bar(x-(n-11)*width/n, whisper_atco2_ny,            width/24, label='ATCO2 (-/n)',         color=c2[1], edgecolor=e2[1])
r7   = ax.bar(x-(n-13)*width/n, whisper_atcosim_ny,          width/24, label='ATCOSIM (-/n)',       color=c2[2], edgecolor=e2[2])
r8   = ax.bar(x-(n-15)*width/n, whisper_atco2_atcosim_ny,    width/24, label='ATCO2-ATCOSIM (-/n)', color=c2[3], edgecolor=e2[3])
r9   = ax.bar(x+(n-15)*width/n, whisper_yn,                  width/24, label='Blank (p/-)',         color=c3[0], edgecolor=e3[0])
r10  = ax.bar(x+(n-13)*width/n, whisper_atco2_yn,            width/24, label='ATCO2 (p/-)',         color=c3[1], edgecolor=e3[1])
r11  = ax.bar(x+(n-11)*width/n, whisper_atcosim_yn,          width/24, label='ATCOSIM (p/-)',       color=c3[2], edgecolor=e3[2])
r12  = ax.bar(x+(n- 9)*width/n, whisper_atco2_atcosim_yn,    width/24, label='ATCO2-ATCOSIM (p/-)', color=c3[3], edgecolor=e3[3])
r13  = ax.bar(x+(n- 7)*width/n, whisper_yy,                  width/24, label='Blank (p/n)',         color=c4[0], edgecolor=e4[0])
r14  = ax.bar(x+(n- 5)*width/n, whisper_atco2_yy,            width/24, label='ATCO2 (p/n)',         color=c4[1], edgecolor=e4[1])
r15  = ax.bar(x+(n- 3)*width/n, whisper_atcosim_yy,          width/24, label='ATCOSIM (p/n)',       color=c4[2], edgecolor=e4[2])
r16  = ax.bar(x+(n- 1)*width/n, whisper_atco2_atcosim_yy,    width/24, label='ATCO2-ATCOSIM (p/n)', color=c4[3], edgecolor=e4[3])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.175), shadow=False, ncol=4, title='Model Variant & Configuration')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)
fig.set_figwidth(15)

# %%
fig.savefig('ANSP_performance_all_validation.pdf', format='pdf', bbox_inches='tight')
fig.savefig('ANSP_performance_all_validation.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# # Extras

# %% [markdown]
# ## Effect of Fine-Tuning on own dataset

# %%
labels = ['ATCO2', 'ATCOSIM', 'A2-AS', 'ANSP']

# Bars          = ['no FT', 'FT']
atco2           = [24.03, 14.66]
atcosim         = [16.74,  1.19]
atco2_atcosim   = [17.06,  2.41]
ansp            = [30.00, 10.00]

bl = [atco2[0], atcosim[0], atco2_atcosim[0], ansp[0]]
ft = [atco2[1], atcosim[1], atco2_atcosim[1], ansp[1]]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.5  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-width/4, bl, width/2, label='Blank', color=[c1[0], c1[1], c1[2], c1[3]], edgecolor=[e1[0], e1[1], e1[2], e1[3]])
r2 = ax.bar(x+width/4, ft, width/2, label='Fine-Tuned', color=[c3[0], c3[1], c3[2], c3[3]], edgecolor=[e3[0], e3[1], e3[2], e3[3]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('WER (%)')
ax.set_title('WER Effect of Fine-Tuning')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.125), shadow=False, ncol=2, title='Model')
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('fine-tuning_effect.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuning_effect.svg', format='svg', bbox_inches='tight')
