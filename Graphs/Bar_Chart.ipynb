# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Normalization and Prompting Effect

# %%
labels = ['ATCO2', 'ATCOSIM', 'Average'] # Norm/Prompt
c1 = [(0.5373, 0.8941, 1.0, 1.0), (0.4549, 1.0, 0.9373, 1.0), (0.9529, 0.6667, 0.5647, 1.0)]
c2 = [(0.5373, 0.8941, 1.0, 0.8), (0.4549, 1.0, 0.9373, 0.8), (0.9529, 0.6667, 0.5647, 0.8)]
c3 = [(0.5373, 0.8941, 1.0, 0.6), (0.4549, 1.0, 0.9373, 0.6), (0.9529, 0.6667, 0.5647, 0.6)]
c4 = [(0.5373, 0.8941, 1.0, 0.4), (0.4549, 1.0, 0.9373, 0.4), (0.9529, 0.6667, 0.5647, 0.4)]

e1 = [(0.0, 0.6510, 0.8392, 1.0), (0.0, 0.6392, 0.5647, 1.0), (0.9216, 0.4471, 0.2745, 1.0)]
e2 = [(0.0, 0.6510, 0.8392, 0.8), (0.0, 0.6392, 0.5647, 0.8), (0.9216, 0.4471, 0.2745, 0.8)]
e3 = [(0.0, 0.6510, 0.8392, 0.6), (0.0, 0.6392, 0.5647, 0.6), (0.9216, 0.4471, 0.2745, 0.6)]
e4 = [(0.0, 0.6510, 0.8392, 0.4), (0.0, 0.6392, 0.5647, 0.4), (0.9216, 0.4471, 0.2745, 0.4)]

nn = [42.27, 78.72, 60.50]
yn = [23.89, 23.44, 23.67]
ny = [23.71, 27.66, 25.69]
yy = [9.73, 3.12, 6.43]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, nn, width/2, label='No Normalizer/No Prompt', color=c1, edgecolor=e1)
r2 = ax.bar(x-width/4, yn, width/2, label='Normalizer/No Prompt', color=c2, edgecolor=e2)
r3 = ax.bar(x+width/4, ny, width/2, label='No Normalizer/Prompt', color=c3, edgecolor=e3)
r4 = ax.bar(x+3*width/4, yy, width/2, label='Normalizer/Prompt', color=c4, edgecolor=e4)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('WER (%)')
ax.set_title('WER Effect of Normalization and Prompting')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.075), shadow=False, ncol=2)
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('wer_effect_normalization_prompting.pdf', format='pdf', bbox_inches='tight')
fig.savefig('wer_effect_norm_prompt.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# # Baseline Performance

# %%
labels = ['ATCO2 T+V', 'ATCO2 V', 'ATCOSIM T+V', 'ATCOSIM V']

#     Blue                       Green                       Red
## Face Color (Soft/Fill)
c1 = [(0.5373, 0.8941, 1.0, 1.0), (0.4549, 1.0, 0.9373, 1.0), (0.9529, 0.6667, 0.5647, 1.0)] # 80% alpha
c2 = [(0.5373, 0.8941, 1.0, 0.8), (0.4549, 1.0, 0.9373, 0.8), (0.9529, 0.6667, 0.5647, 0.8)] # 60% alpha
c3 = [(0.5373, 0.8941, 1.0, 0.6), (0.4549, 1.0, 0.9373, 0.6), (0.9529, 0.6667, 0.5647, 0.6)] # 40% alpha
c4 = [(0.5373, 0.8941, 1.0, 0.4), (0.4549, 1.0, 0.9373, 0.4), (0.9529, 0.6667, 0.5647, 0.4)] # 20% alpha
## Edge Color (Hard/Outline)
e1 = [(0.0, 0.6510, 0.8392, 1.0), (0.0, 0.6392, 0.5647, 1.0), (0.9216, 0.4471, 0.2745, 1.0)] # 80% alpha
e2 = [(0.0, 0.6510, 0.8392, 0.8), (0.0, 0.6392, 0.5647, 0.8), (0.9216, 0.4471, 0.2745, 0.8)] # 60% alpha
e3 = [(0.0, 0.6510, 0.8392, 0.6), (0.0, 0.6392, 0.5647, 0.6), (0.9216, 0.4471, 0.2745, 0.6)] # 40% alpha
e4 = [(0.0, 0.6510, 0.8392, 0.4), (0.0, 0.6392, 0.5647, 0.4), (0.9216, 0.4471, 0.2745, 0.4)] # 20% alpha

# Bars (No/No - Yes/No - No/Yes - Yes/Yes) - Normalizer/Prompt
nn = [71.60, 71.62, 79.70, 79.11]
yn = [31.45, 29.05, 18.14, 17.98]
ny = [63.91, 61.08, 64.10, 63.62]
yy = [27.14, 24.03, 17.10, 16.74]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, nn, width/2, label='No Normalizer/No Prompt', color=[c1[0], c1[0], c1[1], c1[1]], edgecolor=[e1[0], e1[0], e1[1], e1[1]])
r2 = ax.bar(x-width/4, yn, width/2, label='Normalizer/No Prompt', color=[c2[0], c2[0], c2[1], c2[1]], edgecolor=[e2[0], e2[0], e2[1], e2[1]])
r3 = ax.bar(x+width/4, ny, width/2, label='No Normalizer/Prompt', color=[c3[0], c3[0], c3[1], c3[1]], edgecolor=[e3[0], e3[0], e3[1], e3[1]])
r4 = ax.bar(x+3*width/4, yy, width/2, label='Normalizer/Prompt', color=[c4[0], c4[0], c4[1], c4[1]], edgecolor=[e4[0], e4[0], e4[1], e4[1]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('WER (%)')
ax.set_title('Baseline Performance of Whisper Large-v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.075), shadow=False, ncol=2)
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('baseline_performance.pdf', format='pdf', bbox_inches='tight')
fig.savefig('baseline_performance.svg', format='svg', bbox_inches='tight')

# %% [markdown]
# # Fine-Tuning Performance

# %%
labels = ['ATCO2\nT+V', 'ATCO2\nV', 'ATCOSIM\nT+V', 'ATCOSIM\nV', 'A2-AS\nT+V', 'A2-AS\nV']

#     Blue                       Green                       Red                             Yellow
## Face Color (Soft/Fill)
c1 = [(0.5373, 0.8941, 1.0, 1.0), (0.4549, 1.0, 0.9373, 1.0), (0.9529, 0.6667, 0.5647, 1.0), (0.9686, 0.8471, 0.5451, 1.0)] # 80% alpha
c2 = [(0.5373, 0.8941, 1.0, 0.8), (0.4549, 1.0, 0.9373, 0.8), (0.9529, 0.6667, 0.5647, 0.8), (0.9686, 0.8471, 0.5451, 0.8)] # 60% alpha
c3 = [(0.5373, 0.8941, 1.0, 0.6), (0.4549, 1.0, 0.9373, 0.6), (0.9529, 0.6667, 0.5647, 0.6), (0.9686, 0.8471, 0.5451, 0.6)] # 40% alpha
c4 = [(0.5373, 0.8941, 1.0, 0.4), (0.4549, 1.0, 0.9373, 0.4), (0.9529, 0.6667, 0.5647, 0.4), (0.9686, 0.8471, 0.5451, 0.4)] # 20% alpha
## Edge Color (Hard/Outline)
e1 = [(0.0, 0.6510, 0.8392, 1.0), (0.0, 0.6392, 0.5647, 1.0), (0.9216, 0.4471, 0.2745, 1.0), (0.8314, 0.6118, 0.0588, 1.0)] # 80% alpha
e2 = [(0.0, 0.6510, 0.8392, 0.8), (0.0, 0.6392, 0.5647, 0.8), (0.9216, 0.4471, 0.2745, 0.8), (0.8314, 0.6118, 0.0588, 0.8)] # 60% alpha
e3 = [(0.0, 0.6510, 0.8392, 0.6), (0.0, 0.6392, 0.5647, 0.6), (0.9216, 0.4471, 0.2745, 0.6), (0.8314, 0.6118, 0.0588, 0.6)] # 40% alpha
e4 = [(0.0, 0.6510, 0.8392, 0.4), (0.0, 0.6392, 0.5647, 0.4), (0.9216, 0.4471, 0.2745, 0.4), (0.8314, 0.6118, 0.0588,)] # 20% alpha

# Bars
## ATCO2 T+V - ATCO2 V - ATCOSIM T+V - ATCOSIM V - ATCO2-ATCOSIM T+V - ATCO2-ATCOSIM V
whisper = [27.14, 24.03, 17.10, 16.74, 17.87, 17.06]
whisper_atco2 = [5.22, 14.66, 16.05, 15.84, 15.11, 15.78]
whisper_atcosim = [38.62, 34.34, 0.32, 1.19, 3.84, 4.42]
whisper_atco2_atcosim = [4.88, 13.46, 0.25, 1.17, 0.68, 2.41]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(x-3*width/4, whisper, width/2, label='Whisper Large v2 - Blank', color=[c1[0], c1[0], c1[0], c1[0], c1[0], c1[0]], edgecolor=[e1[0], e1[0], e1[0], e1[0], e1[0], e1[0]])
r2 = ax.bar(x-width/4, whisper_atco2, width/2, label='Whisper Large v2 - ATCO2', color=[c1[1], c1[1], c1[1], c1[1], c1[1], c1[1]], edgecolor=[e1[1], e1[1], e1[1], e1[1], e1[1], e1[1]])
r3 = ax.bar(x+width/4, whisper_atcosim, width/2, label='Whisper Large v2 - ATCOSIM', color=[c1[2], c1[2], c1[2], c1[2], c1[2], c1[2]], edgecolor=[e1[2], e1[2], e1[2], e1[2], e1[2], e1[2]])
r4 = ax.bar(x+3*width/4, whisper_atco2_atcosim, width/2, label='Whisper Large v2 - ATCO2-ATCOSIM', color=[c1[3], c1[3], c1[3], c1[3], c1[3], c1[3]], edgecolor=[e1[3], e1[3], e1[3], e1[3], e1[3], e1[3]])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('WER (%)')
ax.set_title('Fine-Tuned Performance of Whisper Large v2')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), shadow=False, ncol=1)
ax.yaxis.grid(color='gray', linestyle='--')
ax.set_axisbelow(True)

# %%
fig.savefig('fine-tuned_performance.pdf', format='pdf', bbox_inches='tight')
fig.savefig('fine-tuned_performance.svg', format='svg', bbox_inches='tight')
